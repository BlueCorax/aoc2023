# %% [markdown]
# # Day 22

# %%
 from collections import defaultdict

# %%
from ipynb.fs.defs.utils import read_lines
puzzle_input = read_lines('day22.txt')

# %%
test_input = """1,0,1~1,2,1
0,0,2~2,0,2
0,2,3~2,2,3
0,0,4~0,2,4
2,0,5~2,2,5
0,1,6~2,1,6
1,1,8~1,1,9""".splitlines()

# %%
def parse_block(line):
    p1, p2 = line.split('~')
    points = p1.split(',') + p2.split(',')
    return tuple(map(int, points))

# %%
def parse_input(inp):
    return [parse_block(l) for l in inp]

# %%
def overlap(s1, e1, s2, e2):
    if s1 > e1:
        return overlap(e1, s1, s2, e2)
    if s2 > e2:
        return overlap(s1, e1, e2, s2)        
    return not ( s2 > e1 or s1 > e2 )

# %%
def collide(brick, other_brick):
    a1, b1, c1, x1, y1, z1 = brick
    a2, b2, c2, x2, y2, z2 = other_brick
    return overlap(a1, x1, a2, x2) and overlap(b1, y1, b2, y2)

# %%
collide((0, 0, 2, 2, 0, 2), (0, 2, 3, 2, 2, 3))
# Out:
# False

# %%
def part1(inp, v= False):
    blocks = parse_input(inp)
    blocks.sort(key=lambda b: min(b[2], b[5]))
    print(blocks)
    stack = []
    tree = defaultdict(list)
    for b in blocks:
        place_at = 0
        for i in reversed(range(len(stack))):
            for other in stack[i]:
                if collide(b, other):
                    if v: print(f'{b} lays on top of {other}')
                    tree[b].append(other)
            if len(tree[b]) > 0:
                place_at = i+1 + abs(b[2] - b[5])
                break
        if v: print(f'{b} lays at {place_at}')
        if place_at >= len(stack):
            for _ in range(place_at - len(stack) + 1):
                stack.append([])
        stack[place_at].append(b)
    if v:
        print(stack)
        for b, below in tree.items():
            print(f'{b} supported by {below}')
        print(tree.items())
    cannot_remove = set([tree[b][0] for b in tree if len(tree[b]) == 1])
    cnt = 0
    for b in blocks:
        if not b in cannot_remove:
            cnt += 1
    return cnt

# %%
part1(test_input, True)
# Out:
# (1, 0, 1, 1, 2, 1) lays at 0
# (0, 0, 2, 2, 0, 2) lays on top of (1, 0, 1, 1, 2, 1)
# (0, 0, 2, 2, 0, 2) lays at 1
# (0, 2, 3, 2, 2, 3) lays on top of (1, 0, 1, 1, 2, 1)
# (0, 2, 3, 2, 2, 3) lays at 1
# (0, 0, 4, 0, 2, 4) lays on top of (0, 0, 2, 2, 0, 2)
# (0, 0, 4, 0, 2, 4) lays on top of (0, 2, 3, 2, 2, 3)
# (0, 0, 4, 0, 2, 4) lays at 2
# (2, 0, 5, 2, 2, 5) lays on top of (0, 0, 2, 2, 0, 2)
# (2, 0, 5, 2, 2, 5) lays on top of (0, 2, 3, 2, 2, 3)
# (2, 0, 5, 2, 2, 5) lays at 2
# (0, 1, 6, 2, 1, 6) lays on top of (0, 0, 4, 0, 2, 4)
# (0, 1, 6, 2, 1, 6) lays on top of (2, 0, 5, 2, 2, 5)
# (0, 1, 6, 2, 1, 6) lays at 3
# (1, 1, 8, 1, 1, 9) lays on top of (0, 1, 6, 2, 1, 6)
# (1, 1, 8, 1, 1, 9) lays at 5
# [[(1, 0, 1, 1, 2, 1)], [(0, 0, 2, 2, 0, 2), (0, 2, 3, 2, 2, 3)], [(0, 0, 4, 0, 2, 4), (2, 0, 5, 2, 2, 5)], [(0, 1, 6, 2, 1, 6)], [], [(1, 1, 8, 1, 1, 9)]]
# (0, 0, 2, 2, 0, 2) supported by [(1, 0, 1, 1, 2, 1)]
# (0, 2, 3, 2, 2, 3) supported by [(1, 0, 1, 1, 2, 1)]
# (0, 0, 4, 0, 2, 4) supported by [(0, 0, 2, 2, 0, 2), (0, 2, 3, 2, 2, 3)]
# (2, 0, 5, 2, 2, 5) supported by [(0, 0, 2, 2, 0, 2), (0, 2, 3, 2, 2, 3)]
# (0, 1, 6, 2, 1, 6) supported by [(0, 0, 4, 0, 2, 4), (2, 0, 5, 2, 2, 5)]
# (1, 1, 8, 1, 1, 9) supported by [(0, 1, 6, 2, 1, 6)]
# dict_items([((0, 0, 2, 2, 0, 2), [(1, 0, 1, 1, 2, 1)]), ((0, 2, 3, 2, 2, 3), [(1, 0, 1, 1, 2, 1)]), ((0, 0, 4, 0, 2, 4), [(0, 0, 2, 2, 0, 2), (0, 2, 3, 2, 2, 3)]), ((2, 0, 5, 2, 2, 5), [(0, 0, 2, 2, 0, 2), (0, 2, 3, 2, 2, 3)]), ((0, 1, 6, 2, 1, 6), [(0, 0, 4, 0, 2, 4), (2, 0, 5, 2, 2, 5)]), ((1, 1, 8, 1, 1, 9), [(0, 1, 6, 2, 1, 6)])])
# 5

# %%
part1(puzzle_input, False)
# Out:
# [(1, 2, 1, 1, 3, 1), (5, 5, 1, 5, 7, 1), (7, 5, 1, 7, 9, 1), (0, 4, 1, 1, 4, 1), (5, 1, 1, 5, 1, 3), (4, 2, 1, 6, 2, 1), (8, 5, 1, 8, 8, 1), (8, 2, 1, 8, 2, 4), (1, 6, 1, 4, 6, 1), (7, 2, 1, 7, 4, 1), (2, 0, 1, 2, 0, 1), (1, 5, 1, 2, 5, 1), (9, 8, 1, 9, 9, 1), (9, 6, 1, 9, 6, 3), (1, 1, 2, 2, 1, 2), (1, 3, 2, 1, 3, 4), (5, 8, 2, 6, 8, 2), (9, 2, 3, 9, 2, 5), (0, 3, 3, 0, 3, 5), (4, 5, 3, 4, 5, 6), (8, 7, 3, 8, 9, 3), (6, 9, 3, 6, 9, 4), (1, 4, 3, 2, 4, 3), (8, 3, 3, 8, 3, 5), (0, 7, 3, 0, 9, 3), (0, 0, 3, 1, 0, 3), (6, 1, 3, 8, 1, 3), (1, 8, 3, 1, 8, 4), (6, 2, 3, 6, 4, 3), (3, 4, 3, 3, 4, 5), (3, 1, 3, 3, 3, 3), (2, 8, 3, 4, 8, 3), (7, 3, 3, 7, 3, 7), (4, 0, 3, 6, 0, 3), (6, 5, 3, 6, 7, 3), (7, 5, 4, 9, 5, 4), (1, 4, 4, 1, 4, 7), (3, 6, 4, 3, 8, 4), (5, 2, 4, 5, 4, 4), (2, 5, 4, 2, 9, 4), (0, 0, 4, 1, 0, 4), (4, 6, 5, 4, 8, 5), (6, 1, 5, 9, 1, 5), (0, 7, 5, 0, 8, 5), (6, 8, 5, 7, 8, 5), (9, 4, 6, 9, 6, 6), (3, 0, 6, 5, 0, 6), (5, 9, 6, 8, 9, 6), (5, 8, 6, 7, 8, 6), (6, 1, 6, 8, 1, 6), (6, 2, 6, 6, 4, 6), (7, 1, 7, 9, 1, 7), (6, 1, 7, 6, 1, 8), (0, 6, 7, 3, 6, 7), (4, 4, 7, 4, 7, 7), (2, 9, 7, 4, 9, 7), (4, 0, 7, 6, 0, 7), (6, 3, 7, 6, 3, 9), (5, 8, 7, 7, 8, 7), (5, 9, 8, 7, 9, 8), (0, 1, 8, 0, 3, 8), (4, 3, 8, 4, 4, 8), (2, 6, 8, 2, 8, 8), (8, 7, 8, 8, 9, 8), (3, 5, 8, 5, 5, 8), (3, 8, 9, 6, 8, 9), (7, 8, 9, 7, 9, 9), (3, 0, 9, 3, 2, 9), (0, 2, 9, 0, 4, 9), (5, 2, 9, 7, 2, 9), (0, 5, 10, 0, 6, 10), (0, 3, 10, 2, 3, 10), (3, 9, 10, 3, 9, 11), (1, 5, 10, 3, 5, 10), (1, 7, 11, 3, 7, 11), (5, 9, 11, 5, 9, 13), (4, 5, 11, 4, 8, 11), (5, 5, 11, 7, 5, 11), (1, 1, 11, 4, 1, 11), (1, 5, 11, 3, 5, 11), (6, 9, 11, 6, 9, 12), (1, 0, 12, 3, 0, 12), (4, 1, 12, 4, 2, 12), (3, 9, 12, 3, 9, 13), (6, 2, 12, 6, 4, 12), (1, 2, 12, 3, 2, 12), (7, 5, 14, 9, 5, 14), (1, 1, 14, 3, 1, 14), (6, 9, 14, 7, 9, 14), (2, 7, 14, 4, 7, 14), (3, 0, 15, 3, 0, 17), (5, 2, 15, 7, 2, 15), (0, 0, 15, 1, 0, 15), (6, 3, 15, 6, 3, 16), (1, 9, 15, 4, 9, 15), (5, 5, 15, 7, 5, 15), (6, 9, 16, 6, 9, 19), (3, 7, 16, 5, 7, 16), (7, 0, 17, 7, 2, 17), (9, 3, 17, 9, 5, 17), (2, 5, 17, 2, 8, 17), (2, 1, 17, 2, 2, 17), (0, 0, 17, 0, 0, 18), (7, 9, 17, 7, 9, 19), (9, 3, 18, 9, 6, 18), (7, 5, 18, 7, 7, 18), (3, 7, 18, 4, 7, 18), (1, 6, 18, 2, 6, 18), (4, 3, 18, 6, 3, 18), (2, 9, 18, 4, 9, 18), (9, 2, 19, 9, 3, 19), (2, 9, 19, 2, 9, 19), (6, 7, 19, 7, 7, 19), (3, 0, 19, 3, 2, 19), (1, 8, 20, 3, 8, 20), (2, 7, 20, 4, 7, 20), (7, 3, 20, 9, 3, 20), (7, 5, 21, 9, 5, 21), (4, 0, 21, 4, 3, 21), (4, 7, 21, 4, 7, 21), (8, 5, 22, 8, 8, 22), (3, 0, 22, 3, 1, 22), (8, 2, 22, 8, 4, 22), (1, 0, 23, 3, 0, 23), (9, 5, 23, 9, 6, 23), (2, 4, 23, 2, 7, 23), (8, 3, 24, 8, 3, 26), (4, 3, 24, 4, 4, 24), (6, 2, 24, 9, 2, 24), (7, 5, 24, 7, 7, 24), (0, 7, 25, 2, 7, 25), (3, 1, 25, 3, 4, 25), (4, 6, 26, 7, 6, 26), (9, 2, 26, 9, 4, 26), (7, 0, 26, 7, 3, 26), (0, 4, 26, 3, 4, 26), (2, 0, 26, 5, 0, 26), (9, 6, 26, 9, 6, 27), (3, 3, 27, 3, 5, 27), (2, 1, 27, 5, 1, 27), (9, 2, 27, 9, 4, 27), (5, 6, 27, 5, 8, 27), (1, 5, 28, 4, 5, 28), (3, 2, 28, 5, 2, 28), (5, 3, 28, 8, 3, 28), (0, 7, 28, 0, 9, 28), (6, 2, 29, 8, 2, 29), (1, 3, 29, 3, 3, 29), (5, 8, 29, 5, 9, 29), (3, 2, 29, 3, 2, 29), (7, 6, 29, 7, 6, 29), (5, 0, 29, 5, 0, 32), (6, 5, 29, 6, 8, 29), (4, 0, 29, 4, 3, 29), (3, 4, 30, 3, 4, 30), (2, 6, 30, 5, 6, 30), (8, 6, 30, 9, 6, 30), (5, 8, 30, 7, 8, 30), (0, 3, 30, 2, 3, 30), (5, 1, 30, 7, 1, 30), (0, 8, 31, 0, 9, 31), (2, 0, 31, 4, 0, 31), (4, 2, 31, 4, 4, 31), (3, 1, 31, 3, 3, 31), (6, 5, 31, 8, 5, 31), (5, 2, 32, 6, 2, 32), (3, 6, 32, 3, 8, 32), (2, 6, 32, 2, 7, 32), (5, 1, 32, 5, 1, 34), (4, 5, 32, 4, 7, 32), (4, 2, 32, 4, 4, 32), (5, 7, 32, 5, 8, 32), (1, 0, 33, 3, 0, 33), (6, 4, 33, 6, 5, 33), (3, 7, 33, 3, 7, 36), (0, 3, 33, 0, 3, 35), (9, 5, 33, 9, 6, 33), (0, 8, 33, 0, 8, 34), (3, 2, 34, 3, 2, 36), (8, 5, 34, 8, 7, 34), (2, 7, 34, 2, 7, 37), (2, 4, 34, 2, 6, 34), (0, 9, 34, 2, 9, 34), (4, 8, 35, 5, 8, 35), (5, 4, 35, 5, 7, 35), (2, 0, 35, 4, 0, 35), (6, 7, 35, 8, 7, 35), (9, 5, 35, 9, 6, 35), (0, ...
# 434
